# %%
from datetime import timedelta

from snowflake.snowpark import Session
from snowflake.snowpark.functions import col
from snowflake.core import Root, CreateMode
from snowflake.core.database import Database
from snowflake.core.schema import Schema
from snowflake.core.stage import Stage
from snowflake.core.table import Table, TableColumn, PrimaryKey
from snowflake.core.task import StoredProcedureCall, Task
from snowflake.core.task.dagv1 import DAGOperation, DAG, DAGTask
from snowflake.core.warehouse import Warehouse

session = Session.builder.configs({"connection_name": "default"}).create()

root = Root(session)


database = root.databases.create(
  Database(
    name="PYTHON_API_DB"),
    mode=CreateMode.if_not_exists
  )

# %%
schema = database.schemas.create(
  Schema(
    name="PYTHON_API_SCHEMA"),
    mode=CreateMode.if_not_exists,
  )

table = schema.tables.create(
  Table(
    name="PYTHON_API_TABLE",
    columns=[
      TableColumn(
        name="TEMPERATURE",
        datatype="int",
        nullable=False,
      ),
      TableColumn(
        name="LOCATION",
        datatype="string",
      ),
    ],
  ),
mode=CreateMode.if_not_exists
)

# %%
table_details = table.fetch()
print("table_details: ", table_details)

table_details.to_dict()
print("table_details as dict: ", table_details.to_dict())
# Out:
# table_details:  name='PYTHON_API_TABLE' kind='PERMANENT' cluster_by=None enable_schema_evolution=False change_tracking=False data_retention_time_in_days=1 max_data_extension_time_in_days=14 default_ddl_collation='' columns=[TableColumn(name='TEMPERATURE', datatype='NUMBER(38,0)', nullable=False, collate=None, default=None, autoincrement=None, autoincrement_start=None, autoincrement_increment=None, constraints=None, comment=None), TableColumn(name='LOCATION', datatype='VARCHAR(16777216)', nullable=True, collate=None, default=None, autoincrement=None, autoincrement_start=None, autoincrement_increment=None, constraints=None, comment=None)] constraints=None comment=None created_on=datetime.datetime(2026, 1, 25, 4, 5, 5, 589000, tzinfo=TzInfo(0)) database_name='PYTHON_API_DB' schema_name='PYTHON_API_SCHEMA' rows=0 bytes=0 owner='ACCOUNTADMIN' dropped_on=None automatic_clustering=False search_optimization=False search_optimization_progress=None search_optimization_bytes=None owner_role_type='ROLE' budget=None table_type='NORMAL'
# table_details as dict:  {'name': 'PYTHON_API_TABLE', 'kind': 'PERMANENT', 'enable_schema_evolution': False, 'change_tracking': False, 'data_retention_time_in_days': 1, 'max_data_extension_time_in_days': 14, 'default_ddl_collation': '', 'columns': [{'name': 'TEMPERATURE', 'datatype': 'NUMBER(38,0)', 'nullable': False}, {'name': 'LOCATION', 'datatype': 'VARCHAR(16777216)', 'nullable': True}], 'created_on': datetime.datetime(2026, 1, 25, 4, 5, 5, 589000, tzinfo=TzInfo(0)), 'database_name': 'PYTHON_API_DB', 'schema_name': 'PYTHON_API_SCHEMA', 'rows': 0, 'bytes': 0, 'owner': 'ACCOUNTADMIN', 'automatic_clustering': False, 'search_optimization': False, 'owner_role_type': 'ROLE', 'table_type': 'NORMAL'}

# %%
try:
    table_details.columns.append(
        TableColumn(
            name="elevation",
            datatype="int",
            nullable=False,
           constraints=[PrimaryKey()],
        )
    )
    table.create_or_alter(table_details)
except Exception as e:
    print("An error occurred:", e)
# Out:
# An error occurred: (400)
# Reason: Bad Request
# Error Message: ambiguous column name 'elevation'
# HTTP response code: 400
# Request ID: 8efdb8af-5db4-431b-9998-a3b9d4f1f256
# Error Code: 002028

# %%
table_details = table.fetch()
existing = {c.name.lower() for c in table_details.columns}

if "elevation" not in existing:
    table_details.columns.append(
        TableColumn(
            name="ELEVATION",
            datatype="int",
            nullable=True,   # safer if table might already have rows
        )
    )
    table.create_or_alter(table_details)
else:
    print("elevation already exists, skipping")
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[20], line 11
#       1 table_details = table.fetch()
#       3 table_details.columns.append(
#       4     TableColumn(            name="elevation",
#       5             datatype="int",
#    (...)      8     )
#       9 )
# ---> 11 table.create_or_alter(table_details)
#      13 table.fetch().to_dict()
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/_internal/telemetry.py:187, in api_telemetry.<locals>.wrap(self, *args, **kwargs)
#     185 telemetry_client.safe_send(event_builder.usage_event())
#     186 try:
# --> 187     r = func(self, *args, **kwargs)
#     188     return r
#     189 except Exception as err:
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/table/_table.py:531, in TableResource.create_or_alter(self, table)
#     499 """Create or alter a table.
#     500
#     501 Parameters
#    (...)    528     - New columns can only be added to the back of the column list.
#     529 """
#     530 table = _fix_table_kind(table)
# --> 531 self.collection._api.create_or_alter_table(
#     532     self.database.name, self.schema.name, self.name, table, async_req=False
#     533 )
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:39, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      37 @functools.wraps(wrapped)
#      38 def wrapper_function(*args, **kwargs):
# ---> 39     return wrapper(*args, **kwargs)
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:136, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     133 if not self.__pydantic_complete__:
#     134     self._create_validators()
# --> 136 res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     137 if self.__return_pydantic_validator__:
#     138     return self.__return_pydantic_validator__(res)
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/table/_generated/api/table_api.py:334, in TableApi.create_or_alter_table(self, database, var_schema, name, table, **kwargs)
#     301 r"""Create a (or alter an existing) table.  # noqa: E501
#     302
#     303 Create a (or alter an existing) table. Even if the operation is just an alter, the full property set must be provided.  # noqa: E501
#    (...)    331 :rtype: Union[SuccessResponse, Future[SuccessResponse]]
#     332 """
#     333 kwargs["_return_http_data_only"] = True
# --> 334 return self.create_or_alter_table_with_http_info(database, var_schema, name, table, **kwargs)
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:39, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      37 @functools.wraps(wrapped)
#      38 def wrapper_function(*args, **kwargs):
# ---> 39     return wrapper(*args, **kwargs)
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:136, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     133 if not self.__pydantic_complete__:
#     134     self._create_validators()
# --> 136 res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     137 if self.__return_pydantic_validator__:
#     138     return self.__return_pydantic_validator__(res)
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/table/_generated/api/table_api.py:479, in TableApi.create_or_alter_table_with_http_info(self, database, var_schema, name, table, **kwargs)
#     460 _auth_settings = ["ExternalOAuth", "KeyPair", "SnowflakeOAuth"]
#     462 _response_types_map = {
#     463     "200": "SuccessResponse",
#     464     "202": "SuccessAcceptedResponse",
#    (...)    476     "504": "ErrorResponse",
#     477 }
# --> 479 return self.api_client.call_api(
#     480     self._root,
#     481     "/api/v2/databases/{database}/schemas/{schema}/tables/{name}",
#     482     "PUT",
#     483     _path_params,
#     484     _query_params,
#     485     _header_params,
#     486     body=_body_params,
#     487     post_params=_form_params,
#     488     files=_files,
#     489     response_types_map=_response_types_map,
#     490     auth_settings=_auth_settings,
#     491     async_req=_params.get("async_req"),
#     492     _return_http_data_only=_params.get("_return_http_data_only"),
#     493     _preload_content=_params.get("_preload_content", True),
#     494     _request_timeout=_params.get("_request_timeout"),
#     495     collection_formats=_collection_formats,
#     496     _request_auth=_params.get("_request_auth"),
#     497     _deserialize_response_fn=self.deserialize,
#     498 )
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/_generated/api_client.py:369, in ApiClient.call_api(self, root, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_types_map, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _request_auth, _deserialize_response_fn)
#     361 logger.debug(
#     362     "request has path params: %r, query_params: %r, header params: %r and body: %r",
#     363     path_params,
#    (...)    366     body,
#     367 )
#     368 if not async_req:
# --> 369     return self.__call_api(
#     370         root,
#     371         resource_path,
#     372         method,
#     373         path_params,
#     374         query_params,
#     375         header_params,
#     376         body,
#     377         post_params,
#     378         files,
#     379         response_types_map,
#     380         auth_settings,
#     381         _return_http_data_only,
#     382         collection_formats,
#     383         _preload_content,
#     384         _request_timeout,
#     385         _host,
#     386         _request_auth,
#     387         _deserialize_response_fn,
#     388     )
#     390 pool = get_thread_pool(root.parameters().max_threads)
#     391 return pool.submit(
#     392     self.__call_api,
#     393     *(
#    (...)    412     ),
#     413 )
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/_generated/api_client.py:209, in ApiClient.__call_api(self, root, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_types_map, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _request_auth, _deserialize_response_fn)
#     207     if e.body:
#     208         e.body = e.body.decode("utf-8")
# --> 209     raise e
#     211 self.last_response = response_data
#     213 return_data = response_data
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/_generated/api_client.py:195, in ApiClient.__call_api(self, root, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_types_map, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _request_auth, _deserialize_response_fn)
#     191     url += "?" + url_query
#     193 try:
#     194     # perform request and return response, maybe with retry
# --> 195     response_data = self.request_with_retry(
#     196         root,
#     197         method,
#     198         url,
#     199         query_params=query_params,
#     200         headers=header_params,
#     201         post_params=post_params,
#     202         body=body,
#     203         _preload_content=_preload_content,
#     204         _request_timeout=_request_timeout,
#     205     )
#     206 except APIError as e:
#     207     if e.body:
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/_generated/api_client.py:429, in ApiClient.request_with_retry(self, root, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     427 """Response time by default one hour"""
#     428 enter_timing = time.time()
# --> 429 response_data = self.request(
#     430     root,
#     431     method,
#     432     url,
#     433     query_params=query_params,
#     434     headers=headers,
#     435     post_params=post_params,
#     436     body=body,
#     437     _preload_content=_preload_content,
#     438     _request_timeout=_request_timeout,
#     439 )
#     441 if not root.parameters().should_retry_request or response_data.status not in rest.RETRY_STATUS_CODES:
#     442     return response_data
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/_generated/api_client.py:557, in ApiClient.request(self, root, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     555 elif method == "PUT":
#     556     try:
# --> 557         return self.rest_client.put_request(
#     558             root,
#     559             url,
#     560             query_params=query_params,
#     561             headers=headers,
#     562             post_params=post_params,
#     563             _preload_content=_preload_content,
#     564             _request_timeout=_request_timeout,
#     565             body=body,
#     566         )
#     567     except APIError as error:
#     568         # Raise a more helpful user error if CoA is not supported for this resource;
#     569         # this is represented as either 405 or 501 on the server.
#     570         if error.status in (405, 501):
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/_generated/rest.py:314, in RESTClientObject.put_request(self, root, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     303 def put_request(
#     304     self,
#     305     root,
#    (...)    312     _request_timeout=None,
#     313 ):
# --> 314     return self.request(
#     315         root,
#     316         "PUT",
#     317         url,
#     318         headers=headers,
#     319         query_params=query_params,
#     320         post_params=post_params,
#     321         _preload_content=_preload_content,
#     322         _request_timeout=_request_timeout,
#     323         body=body,
#     324     )
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/_generated/rest.py:203, in RESTClientObject.request(self, root, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     200     # log response body
#     201     logger.debug("response body: %s", r.data)
# --> 203 return evaluate_status_codes(root, r)
#
# File ~/projects/snowflake-env/lib/python3.12/site-packages/snowflake/core/_generated/rest.py:61, in evaluate_status_codes(root, r)
#      58     if 500 <= r.status <= 599:
#      59         raise ServerError(http_resp=r, root=root)
# ---> 61     raise APIError(http_resp=r, root=root)
#      63 return r
#
# APIError: (400)
# Reason: Bad Request
# Error Message: ambiguous column name 'elevation'
# HTTP response code: 400
# Request ID: 60f71286-1c16-4dcf-9931-bb589f95a5ed
# Error Code: 002028

# %%
table.fetch().to_dict()
# Out:
# {'name': 'PYTHON_API_TABLE',
#  'kind': 'PERMANENT',
#  'enable_schema_evolution': False,
#  'change_tracking': False,
#  'data_retention_time_in_days': 1,
#  'max_data_extension_time_in_days': 14,
#  'default_ddl_collation': '',
#  'columns': [{'name': 'TEMPERATURE',
#    'datatype': 'NUMBER(38,0)',
#    'nullable': False},
#   {'name': 'LOCATION', 'datatype': 'VARCHAR(16777216)', 'nullable': True},
#   {'name': 'ELEVATION', 'datatype': 'NUMBER(38,0)', 'nullable': False}],
#  'constraints': [{'name': 'ELEVATION',
#    'column_names': ['ELEVATION'],
#    'constraint_type': 'PRIMARY KEY'}],
#  'created_on': datetime.datetime(2026, 1, 25, 4, 5, 5, 589000, tzinfo=TzInfo(0)),
#  'database_name': 'PYTHON_API_DB',
#  'schema_name': 'PYTHON_API_SCHEMA',
#  'rows': 0,
#  'bytes': 0,
#  'owner': 'ACCOUNTADMIN',
#  'automatic_clustering': False,
#  'search_optimization': False,
#  'owner_role_type': 'ROLE',
#  'table_type': 'NORMAL'}

# %%
warehouses = root.warehouses

python_api_wh = Warehouse(
    name="PYTHON_API_WH",
    warehouse_size="SMALL",
    auto_suspend=500,
)

warehouse = warehouses.create(python_api_wh,mode=CreateMode.or_replace)

print("warehouse: ",warehouse)


warehouse_details = warehouse.fetch()
warehouse_details.to_dict()
warehouse.drop()
# Out:
# warehouse:  <WarehouseResource: 'PYTHON_API_WH'>

# %%
database = root.databases.create(
  Database(
    name="PYTHON_API_DB"),
    mode=CreateMode.or_replace
  )

schema = database.schemas.create(
  Schema(
    name="PYTHON_API_SCHEMA"),
    mode=CreateMode.or_replace,
  )

# %%
stages = root.databases[database.name].schemas[schema.name].stages
stages.create(Stage(name="TASKS_STAGE"))

def trunc(session: Session, from_table: str, to_table: str, count: int) -> str:
  (
    session
    .table(from_table)
    .limit(count)
    .write.save_as_table(to_table)
  )
  return "Truncated table successfully created!"

def filter_by_shipmode(session: Session, mode: str) -> str:
  (
    session
    .table("snowflake_sample_data.tpch_sf100.lineitem")
    .filter(col("L_SHIPMODE") == mode)
    .limit(10)
    .write.save_as_table("filter_table")
  )
  return "Filter table successfully created!"
